# %% [markdown]
# <a href="https://colab.research.google.com/github/mrsmarried2thegame/coding-club_data-exploratiom-w-pandas/blob/main/Data_Exploration_with_Pandas_College_Major_v_s_Your_Salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to an intoduction to the Python library PANDAS!")
# Out:
# Welcome to an intoduction to the Python library PANDAS!

# %%
import pandas as pd

# Surppressing the warnings:
#import warnings
#warnings.filterwarnings('ignore')

df = pd.read_csv('salaries_by_college_major.csv')

# %%
df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
# If I wanted to see a certain rows of the data frame
df.head(20).T
# T = Trampose
# Out:
#                                            0                      1   \
# Undergraduate Major                Accounting  Aerospace Engineering
# Starting Median Salary                46000.0                57700.0
# Mid-Career Median Salary              77100.0               101000.0
# Mid-Career 10th Percentile Salary     42200.0                64300.0
# Mid-Career 90th Percentile Salary    152000.0               161000.0
# Group                                Business                   STEM
#
#                                             2             3             4   \
# Undergraduate Major                Agriculture  Anthropology  Architecture
# Starting Median Salary                 42600.0       36800.0       41600.0
# Mid-Career Median Salary               71900.0       61500.0       76800.0
# Mid-Career 10th Percentile Salary      36300.0       33800.0       50600.0
# Mid-Career 90th Percentile Salary     150000.0      138000.0      136000.0
# ...

# %% [markdown]
# Questions to answer:
#
# How many rows does our dataframe have?
#
# **51 Rows**
#
# How many columns does it have?
#
# **6 Columns**
#
# What are the labels for the columns? Do the columns have names?
#
# *   **Undergraduate Major**
# *   **Starting Median Salary**
# *   **Mid-Career Median Salary**
# *   **Mid-Career 10th Percentile Salary**
# *   **Mid-Career 90th Percentile Salary**
# *   **Group**
#
# Are there any missing values in our dataframe? Does our dataframe contain any bad data?

# %%
df.shape
# Out:
# (51, 6)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
# One of the ways to check missing values in the dataset:
df.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
# Another way:
df.isnull().T
# Out:
#                                       0      1      2      3      4      5   \
# Undergraduate Major                False  False  False  False  False  False
# Starting Median Salary             False  False  False  False  False  False
# Mid-Career Median Salary           False  False  False  False  False  False
# Mid-Career 10th Percentile Salary  False  False  False  False  False  False
# Mid-Career 90th Percentile Salary  False  False  False  False  False  False
# Group                              False  False  False  False  False  False
#
#                                       6      7      8      9   ...     41  \
# Undergraduate Major                False  False  False  False  ...  False
# Starting Median Salary             False  False  False  False  ...  False
# Mid-Career Median Salary           False  False  False  False  ...  False
# Mid-Career 10th Percentile Salary  False  False  False  False  ...  False
# ...

# %%
df.tail()
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 46             Psychology                 35900.0                   60400.0
# 47               Religion                 34100.0                   52000.0
# 48              Sociology                 36500.0                   58200.0
# 49                Spanish                 34000.0                   53100.0
# 50  Source: PayScale Inc.                     NaN                       NaN
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS
# 50                                NaN                                NaN   NaN

# %%
# Delete the last row (becuase it has at least 1 missing value )
new_df = df.dropna()
new_df.tail()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 45   Political Science                 40800.0                   78200.0
# 46          Psychology                 35900.0                   60400.0
# 47            Religion                 34100.0                   52000.0
# 48           Sociology                 36500.0                   58200.0
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 45                            41200.0                           168000.0  HASS
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS

# %% [markdown]
# To delete a specific row, for example, the row at index 50, you would use the `drop()` method:

# %%
df_after_dropping_row_50 = Expirement.drop(index=50)
display(df_after_dropping_row_50.tail())
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 45   Political Science                 40800.0                   78200.0
# 46          Psychology                 35900.0                   60400.0
# 47            Religion                 34100.0                   52000.0
# 48           Sociology                 36500.0                   58200.0
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 45                            41200.0                           168000.0  HASS
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS

# %% [markdown]
# Notice that the last row (index 50) is now gone. The `Expirement` DataFrame itself remains unchanged unless you assign the result back to it or use `inplace=True`.

# %%
# To drop a specific row
dropped_row = df.drop(index = 3)
dropped_row.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 4           Architecture                 41600.0                   76800.0
# 5            Art History                 35800.0                   64900.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 4                            50600.0                           136000.0
# 5                            28800.0                           125000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 4  Business
# 5      HASS

# %%
# to see the maximium salary a new grad can get with a degree without mentioning the degree itself
Rich = new_df['Starting Median Salary'].max()
print(f"Ayo! you be making ${Rich}!! Good call on going to college")
# Out:
# Ayo! you be making $74300.0!! Good call on going to college

# %%
# Vise versa
Result = new_df['Starting Median Salary'].min()
print(f"The lowest a new grad can go is ${Result}")
# Out:
# The lowest a new grad can go is $34000.0

# %%
# BUT to know the specifics:
Degree = new_df['Starting Median Salary'].idxmax()
print(Degree)
# Out:
# 43

# %%
# Again vise versa:
bad = new_df['Starting Median Salary'].idxmin()
print(bad)
# Out:
# 49

# %%
new_df.loc[49]
# Out:
# Undergraduate Major                  Spanish
# Starting Median Salary               34000.0
# Mid-Career Median Salary             53100.0
# Mid-Career 10th Percentile Salary    31000.0
# Mid-Career 90th Percentile Salary    96400.0
# Group                                   HASS
# Name: 49, dtype: object

# %%
new_df['Undergraduate Major'].loc[43]
# Out:
# 'Physician Assistant'

# %%
# To call the row and see al info
new_df.loc[43]
# Out:
# Undergraduate Major                  Physician Assistant
# Starting Median Salary                           74300.0
# Mid-Career Median Salary                         91700.0
# Mid-Career 10th Percentile Salary                66400.0
# Mid-Career 90th Percentile Salary               124000.0
# Group                                               STEM
# Name: 43, dtype: object

# %% [markdown]
# What college major has the highest mid-career salary? How much do graduates with this major earn? (Mid-career is defined as having 10+ years of experience).
#
# Which college major has the lowest starting salary and how much do graduates earn after university?
#
# Which college major has the lowest mid-career salary and how much can people expect to earn with this degree?
